# %%
import pandas as pd

# %%
df=pd.read_csv("survey_results_public.csv",index_col= "ResponseId")
result_schema = pd.read_csv('survey_results_schema.csv',index_col= "qname")

# %%
pd.set_option("display.max_columns",48)
pd.set_option("display.max_rows",40)

# %%
df.head(3)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
#
#                        Country US_State UK_Country  \
# ResponseId
# 1                     Slovakia      NaN        NaN
# 2                  Netherlands      NaN        NaN
# 3           Russian Federation      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# ...

# %%
df.rename(columns={"MainBranch":"subbranch"},inplace=True)

# %%
df.head(5)
# Out:
#                                                     subbranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df["NEWOtherComms"].map({"Yes": True ,"No": False} )
# Out:
# ResponseId
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# 83439    False
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df["NEWOtherComms"]=df["NEWOtherComms"].map({"Yes": True ,"No": False} )

# %%
df.head(2)
# Out:
#                                          subbranch  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State UK_Country  \
# ResponseId
# 1               NaN        NaN
# 2               NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# ...

# %%
df["SOAccount"]=df["SOAccount"].replace({"Yes": True ,"No": False} )

# %%
df.head(2)
# Out:
#                                          subbranch  \
# ResponseId
# 1                   I am a developer by profession
# 2           I am a student who is learning to code
#
#                                                    Employment      Country  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...     Slovakia
# 2                                          Student, full-time  Netherlands
#
#            US_State UK_Country  \
# ResponseId
# 1               NaN        NaN
# 2               NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                                     LearnCode YearsCode  \
# ResponseId
# 1           Coding Bootcamp;Other online resources (ex: vi...       NaN
# ...
