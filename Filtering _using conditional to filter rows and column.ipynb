# %%
import pandas as pd

# %%
df=pd.read_csv("survey_results_public.csv",index_col= "ResponseId")
result_schema = pd.read_csv('survey_results_schema.csv',index_col= "qname")

# %%
pd.set_option("display.max_columns",48)
pd.set_option("display.max_rows",40)

# %%
result_schema
# Out:
#                   qid                                           question  \
# qname
# S0              QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo        QID12                                  Browser Meta Info
# S1               QID1  <span style="font-size:22px; font-family: aria...
# MainBranch       QID2  Which of the following options best describes ...
# Employment      QID24  Which of the following best describes your cur...
# ...               ...                                                ...
# Accessibility  QID124  Which of the following describe you, if any? P...
# MentalHealth   QID125  Which of the following describe you, if any? P...
# S6             QID131  <span style="font-size:22px;"><strong>Final Qu...
# SurveyLength   QID132  How do you feel about the length of the survey...
# SurveyEase     QID133  How easy or difficult was this survey to compl...
#
#                force_resp  type selector
# qname
# ...

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.loc[20:24]
# Out:
#                                                    MainBranch  \
# ResponseId
# 20          I used to be a developer by profession, but no...
# 21                             I am a developer by profession
# 22                     I am a student who is learning to code
# 23                     I am a student who is learning to code
# 24                             I am a developer by profession
#
#                     Employment  Country US_State UK_Country  \
# ResponseId
# 20          Employed full-time   Brazil      NaN        NaN
# 21          Student, full-time  Germany      NaN        NaN
# 22          Student, full-time   Sweden      NaN        NaN
# 23          Student, full-time    India      NaN        NaN
# 24          Employed full-time   France      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 20               Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.loc[1:40,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1         C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 2                                     JavaScript;Python
# 3                              Assembly;C;Python;R;Rust
# 4                                 JavaScript;TypeScript
# 5                        Bash/Shell;HTML/CSS;Python;SQL
# 6     C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 7                                   HTML/CSS;JavaScript
# 8           HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript
# 9                                   HTML/CSS;JavaScript
# 10                                           C++;Python
# 11                                        C#;TypeScript
# 12    Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...
# 13                                 C;C++;Java;Perl;Ruby
# 14                        C;C++;JavaScript;Python;R;SQL
# 15                                       JavaScript;SQL
# 16                                    Bash/Shell;Python
# 17                  C#;HTML/CSS;Java;JavaScript;Node.js
# ...

# %%
salart_max=df['ConvertedCompYearly']>10000000

# %%
df.loc[salart_max,['LanguageWantToWorkWith','DatabaseHaveWorkedWith','Age','ConvertedCompYearly']].head(4)
# Out:
#                                        LanguageWantToWorkWith  \
# ResponseId
# 3734        Bash/Shell;Groovy;HTML/CSS;Java;JavaScript;Nod...
# 5306                                          Python;Rust;SQL
# 7206                    Bash/Shell;C#;HTML/CSS;JavaScript;SQL
# 7905                                        Objective-C;Swift
#
#                        DatabaseHaveWorkedWith              Age  \
# ResponseId
# 3734                   MariaDB;MongoDB;Oracle  35-44 years old
# 5306                                      NaN  35-44 years old
# 7206        Microsoft SQL Server;MySQL;Oracle  35-44 years old
# 7905                                   SQLite  25-34 years old
#
#             ConvertedCompYearly
# ResponseId
# 3734                 11250000.0
# 5306                 15000000.0
# 7206                 12500000.0
# 7905                 10500000.0

# %%
country=['india','germany','Brazil','Austria']
filt=df['Country'].isin(country)

# %%
df.loc[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 4                              I am a developer by profession
# 20          I used to be a developer by profession, but no...
# 46                             I am a developer by profession
# 124                            I am a developer by profession
# 255                            I am a developer by profession
# ...                                                       ...
# 83393                          I am a developer by profession
# 83420                          I am a developer by profession
# 83429                          I am a developer by profession
# 83434                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  Country  \
# ResponseId
# 4                                          Employed full-time  Austria
# ...

# %%
df.loc[83439,'LanguageWantToWorkWith']
# Out:
# 'Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQL;TypeScript'

# %%
df.loc[1:40,['LanguageWantToWorkWith']]
# Out:
#                                        LanguageWantToWorkWith
# ResponseId
# 1                                                       Swift
# 2                                                         NaN
# 3                                           Julia;Python;Rust
# 4                                       JavaScript;TypeScript
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# 6           C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 7                                     HTML/CSS;JavaScript;PHP
# 8                                                        Ruby
# 9                                         HTML/CSS;JavaScript
# 10                                             Haskell;Python
# 11                                                         C#
# 12          C++;Clojure;JavaScript;Node.js;Rust;SQL;TypeSc...
# 13                                                       Rust
# 14                                                        NaN
# ...

# %%
filt_2=df ['LanguageWantToWorkWith'].str.contains('Python',na=False)

# %%
df.loc[filt_2,['Country','LanguageWantToWorkWith']]
# Out:
#                                                       Country  \
# ResponseId
# 3                                          Russian Federation
# 5           United Kingdom of Great Britain and Northern I...
# 6                                    United States of America
# 10                                                     Sweden
# 16                                   United States of America
# ...                                                       ...
# 83427                                United States of America
# 83428                                United States of America
# 83430                                United States of America
# 83432                                                Pakistan
# 83437                                United States of America
#
#                                        LanguageWantToWorkWith
# ResponseId
# 3                                           Julia;Python;Rust
# 5                              Bash/Shell;HTML/CSS;Python;SQL
# ...
