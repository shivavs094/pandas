# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv',index_col='ResponseId')

# %%
pd.set_option('display.max_column',48)
pd.set_option('display.max_rows',50)

# %%
df.head(5)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df.sort_values(by=['Country','ConvertedCompYearly'],inplace=True)

# %%
df[['Country','Age','ConvertedCompYearly']].head(20)
# Out:
#                 Country                 Age  ConvertedCompYearly
# ResponseId
# 55151       Afghanistan     35-44 years old                100.0
# 17121       Afghanistan     18-24 years old               3108.0
# 14883       Afghanistan     25-34 years old               4200.0
# 51429       Afghanistan     25-34 years old               4668.0
# 17487       Afghanistan     25-34 years old               5448.0
# 11378       Afghanistan     25-34 years old               9792.0
# 44641       Afghanistan     25-34 years old              15132.0
# 31087       Afghanistan     25-34 years old              23964.0
# 27199       Afghanistan     25-34 years old              51804.0
# 22667       Afghanistan     45-54 years old             155496.0
# 65400       Afghanistan     35-44 years old           30468516.0
# 37432       Afghanistan  Under 18 years old                  NaN
# 11462       Afghanistan     18-24 years old                  NaN
# ...

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 66911    45241312.0
# 65400    30468516.0
# 40587    21822250.0
# 28792    20000000.0
# 12701    19200000.0
# 9609     17500000.0
# 5306     15000000.0
# 12904    14411628.0
# 66489    12750000.0
# 47564    12500000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10,'ConvertedCompYearly')
# Out:
#                                                    MainBranch  \
# ResponseId
# 66911                          I am a developer by profession
# 65400                          I am a developer by profession
# 40587                          I am a developer by profession
# 28792                          I am a developer by profession
# 12701                          I am a developer by profession
# 9609        I am not primarily a developer, but I write co...
# 5306                           I am a developer by profession
# 12904                          I am a developer by profession
# 66489                          I am a developer by profession
# 47564                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 66911                                     I prefer not to say
# 65400                                      Employed full-time
# 40587                                      Employed full-time
# ...
