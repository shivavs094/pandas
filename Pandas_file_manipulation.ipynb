# %%
import pandas as pd

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
#  12  OrgSize                       60726 non-null  object
#  13  Currency                      61080 non-null  object
#  14  CompTotal                     47183 non-null  float64
#  15  CompFreq                      52150 non-null  object
#  16  LanguageHaveWorkedWith        82357 non-null  object
#  17  LanguageWantToWorkWith        76821 non-null  object
#  18  DatabaseHaveWorkedWith        69546 non-null  object
#  19  DatabaseWantToWorkWith        58299 non-null  object
#  20  PlatformHaveWorkedWith        52135 non-null  object
#  21  PlatformWantToWorkWith        41619 non-null  object
#  22  WebframeHaveWorkedWith        61707 non-null  object
#  23  WebframeWantToWorkWith        52095 non-null  object
#  24  MiscTechHaveWorkedWith        47055 non-null  object
#  25  MiscTechWantToWorkWith        38021 non-null  object
#  26  ToolsTechHaveWorkedWith       72537 non-null  object
#  27  ToolsTechWantToWorkWith       65480 non-null  object
#  28  NEWCollabToolsHaveWorkedWith  81234 non-null  object
#  29  NEWCollabToolsWantToWorkWith  73022 non-null  object
#  30  OpSys                         83294 non-null  object
#  31  NEWStuck                      83052 non-null  object
#  32  NEWSOSites                    83171 non-null  object
#  33  SOVisitFreq                   82413 non-null  object
#  34  SOAccount                     82525 non-null  object
#  35  SOPartFreq                    67553 non-null  object
#  36  SOComm                        82319 non-null  object
#  37  NEWOtherComms                 82828 non-null  object
#  38  Age                           82407 non-null  object
#  39  Gender                        82286 non-null  object
#  40  Trans                         80678 non-null  object
#  41  Sexuality                     73366 non-null  object
#  42  Ethnicity                     79464 non-null  object
#  43  Accessibility                 77603 non-null  object
#  44  MentalHealth                  76920 non-null  object
#  45  SurveyLength                  81711 non-null  object
#  46  SurveyEase                    81948 non-null  object
#  47  ConvertedCompYearly           46844 non-null  float64
# dtypes: float64(2), int64(1), object(45)
# memory usage: 30.6+ MB

# %%
pd.set_option("display.max_columns",48)
pd.set_option("display.max_rows",48)

# %%
df.iloc[1:20,10:15]
# Out:
#    YearsCodePro                                            DevType  \
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                               Developer, front-end
# 4            10  Developer, desktop or enterprise applications;...
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8             4                               Developer, front-end
# 9             4      Data scientist or machine learning specialist
# 10           10                                Developer, back-end
# 11            5                                Developer, back-end
# 12            6  Developer, desktop or enterprise applications;...
# 13          NaN      Data scientist or machine learning specialist
# 14          NaN                                                NaN
# 15          NaN                                                NaN
# 16            2                              Developer, full-stack
# 17            6  Developer, front-end;Developer, full-stack;Dev...
# 18           30                                                NaN
# 19            9                            Other (please specify):
#
#                                               OrgSize               Currency  \
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                100 to 499 employees      EUR European Euro
# 4   Just me - I am a freelancer, sole proprietor, ...    GBP\tPound sterling
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                            10,000 or more employees      INR\tIndian rupee
# 9                                  10 to 19 employees     SEK\tSwedish krona
# 10                           10,000 or more employees    GBP\tPound sterling
# 11                                 10 to 19 employees      EUR European Euro
# 12                           1,000 to 4,999 employees      EUR European Euro
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                               100 to 499 employees      TRY\tTurkish lira
# 17                               500 to 999 employees   CAD\tCanadian dollar
# 18                           5,000 to 9,999 employees  SGD\tSingapore dollar
# 19                                                NaN                    NaN
#
#     CompTotal
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     42000.0
# 10        NaN
# 11    43000.0
# 12    71500.0
# 13        NaN
# 14        NaN
# 15        NaN
# 16     9000.0
# 17    61000.0
# 18    18700.0
# 19        NaN

# %%
df.taill(20)
# Out:
#        ResponseId                                         MainBranch  \
# 83419       83420                     I am a developer by profession
# 83420       83421                     I am a developer by profession
# 83421       83422                     I am a developer by profession
# 83422       83423  I am not primarily a developer, but I write co...
# 83423       83424                     I am a developer by profession
# 83424       83425                     I am a developer by profession
# 83425       83426                     I am a developer by profession
# 83426       83427                     I am a developer by profession
# 83427       83428                     I am a developer by profession
# 83428       83429                     I am a developer by profession
# 83429       83430                        I code primarily as a hobby
# 83430       83431                     I am a developer by profession
# 83431       83432                     I am a developer by profession
# 83432       83433                     I am a developer by profession
# 83433       83434                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 83419                                 Employed full-time
# 83420                                 Employed full-time
# 83421  Independent contractor, freelancer, or self-em...
# 83422  Independent contractor, freelancer, or self-em...
# 83423                                 Employed part-time
# 83424                                 Employed full-time
# 83425                                 Employed full-time
# 83426                                 Employed full-time
# 83427                                 Employed full-time
# 83428                                 Employed full-time
# 83429                 Not employed, but looking for work
# 83430                                 Employed full-time
# 83431  Independent contractor, freelancer, or self-em...
# 83432                                 Employed full-time
# 83433  Independent contractor, freelancer, or self-em...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country      US_State UK_Country  \
# 83419                   Austria           NaN        NaN
# 83420                    France           NaN        NaN
# 83421                    Norway           NaN        NaN
# 83422                  Viet Nam           NaN        NaN
# 83423                  Cameroon           NaN        NaN
# 83424                   Germany           NaN        NaN
# 83425                   Finland           NaN        NaN
# 83426  United States of America      Nebraska        NaN
# 83427  United States of America  Pennsylvania        NaN
# 83428                    Brazil           NaN        NaN
# 83429  United States of America    Washington        NaN
# 83430  United States of America      Illinois        NaN
# 83431                  Pakistan           NaN        NaN
# 83432                    Canada           NaN        NaN
# 83433                    Brazil           NaN        NaN
# 83434  United States of America         Texas        NaN
# 83435                     Benin           NaN        NaN
# 83436  United States of America    New Jersey        NaN
# 83437                    Canada           NaN        NaN
# 83438                    Brazil           NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 83419    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
# 83420    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
# 83421       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83422       Bachelor’s degree (B.A., B.S., B.Eng., etc.)   5 - 10 years
# 83423    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  18 - 24 years
# 83424       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83425  Secondary school (e.g. American high school, G...  11 - 17 years
# 83426       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83427       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83428    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  18 - 24 years
# 83429       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83430    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 83431       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83433       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 83434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83435       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83436  Secondary school (e.g. American high school, G...  11 - 17 years
# 83437       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 83438                 Professional degree (JD, MD, etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  \
# 83419  Other online resources (ex: videos, blogs, etc...        30
# 83420  Other online resources (ex: videos, blogs, etc...        16
# 83421  School;Friend or family member;Online Courses ...        20
# 83422  Other online resources (ex: videos, blogs, etc...        26
# 83423                                             School         7
# 83424  Other online resources (ex: videos, blogs, etc...        17
# 83425  Other online resources (ex: videos, blogs, etc...         5
# 83426  Other online resources (ex: videos, blogs, etc...        11
# 83427  Other online resources (ex: videos, blogs, etc...        13
# 83428                                             School        12
# 83429    Other online resources (ex: videos, blogs, etc)         6
# 83430  Other online resources (ex: videos, blogs, etc...        23
# 83431  Other online resources (ex: videos, blogs, etc...         9
# 83432                                             School         5
# 83433  Online Forum;Online Courses or Certification;O...        15
# 83434  Other online resources (ex: videos, blogs, etc...         6
# 83435  Other online resources (ex: videos, blogs, etc...         4
# 83436                                             School        10
# 83437  Online Courses or Certification;Books / Physic...         5
# 83438                                             School        14
#
#            YearsCodePro                                            DevType  \
# 83419                13  Developer, front-end;Developer, desktop or ent...
# 83420                 4  Developer, front-end;Developer, desktop or ent...
# 83421                15                              Developer, full-stack
# 83422                18                              Developer, full-stack
# 83423                 5                              Developer, full-stack
# 83424                12  Developer, full-stack;Other (please specify):;...
# 83425                 3                              Developer, full-stack
# 83426                 2  Developer, front-end;Developer, desktop or ent...
# 83427                 2  Developer, front-end;Developer, desktop or ent...
# 83428                 7               Senior Executive (C-Suite, VP, etc.)
# 83429               NaN                    Other (please specify):;Student
# 83430                21  Developer, front-end;Developer, full-stack;Dev...
# 83431                 4  Developer, mobile;Developer, desktop or enterp...
# 83432  Less than 1 year                                Developer, back-end
# 83433                11  Developer, mobile;Developer, front-end;Develop...
# 83434                 5                                Developer, back-end
# 83435                 2                              Developer, full-stack
# 83436                 4  Data scientist or machine learning specialist;...
# 83437                 3                                Developer, back-end
# 83438                 4  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 83419                               100 to 499 employees
# 83420                                   2 to 9 employees
# 83421                               100 to 499 employees
# 83422  Just me - I am a freelancer, sole proprietor, ...
# 83423                                 20 to 99 employees
# 83424                           10,000 or more employees
# 83425                                 10 to 19 employees
# 83426                               500 to 999 employees
# 83427                           1,000 to 4,999 employees
# 83428                                 20 to 99 employees
# 83429                                                NaN
# 83430                                 10 to 19 employees
# 83431                                   2 to 9 employees
# 83432                           10,000 or more employees
# 83433                           1,000 to 4,999 employees
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 83419            EUR European Euro    77000.0   Yearly
# 83420            EUR European Euro    33000.0   Yearly
# 83421         NOK\tNorwegian krone   820000.0   Yearly
# 83422    USD\tUnited States dollar    20000.0   Yearly
# 83423    USD\tUnited States dollar      500.0   Weekly
# 83424            EUR European Euro   120000.0   Yearly
# 83425            EUR European Euro     1500.0  Monthly
# 83426    USD\tUnited States dollar        NaN      NaN
# 83427    USD\tUnited States dollar    86000.0   Weekly
# 83428          BRL\tBrazilian real    15000.0  Monthly
# 83429                          NaN        NaN      NaN
# 83430    USD\tUnited States dollar   125000.0   Yearly
# 83431         PKR\tPakistani rupee   150000.0  Monthly
# 83432         CAD\tCanadian dollar   106000.0   Yearly
# 83433          BRL\tBrazilian real    80000.0   Yearly
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                                   LanguageHaveWorkedWith  \
# 83419  Groovy;HTML/CSS;Java;JavaScript;Node.js;PHP;Po...
# 83420  Bash/Shell;C#;C++;Go;Groovy;HTML/CSS;Java;Java...
# 83421  Bash/Shell;HTML/CSS;JavaScript;Node.js;Python;...
# 83422                       HTML/CSS;JavaScript;PHP;Ruby
# 83423                 HTML/CSS;JavaScript;PHP;Python;SQL
# 83424           Bash/Shell;C;Go;Java;JavaScript;Perl;SQL
# 83425             HTML/CSS;JavaScript;Node.js;TypeScript
# 83426     Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL
# 83427                                        Java;Python
# 83428                      Bash/Shell;Node.js;TypeScript
# 83429             HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430        APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431  C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83432                                               Ruby
# 83433      Java;JavaScript;Kotlin;Objective-C;TypeScript
# 83434                                 Clojure;Kotlin;SQL
# 83435                                                NaN
# 83436                                 Groovy;Java;Python
# 83437               Bash/Shell;JavaScript;Node.js;Python
# 83438             Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 83419  HTML/CSS;Java;JavaScript;Kotlin;Node.js;TypeSc...
# 83420  HTML/CSS;Java;JavaScript;Node.js;Python;TypeSc...
# 83421  Bash/Shell;HTML/CSS;JavaScript;Node.js;Python;...
# 83422                                      HTML/CSS;Ruby
# 83423                 HTML/CSS;JavaScript;PHP;Python;SQL
# 83424                           Bash/Shell;Java;Rust;SQL
# 83425                                                NaN
# 83426              Bash/Shell;Java;JavaScript;Python;SQL
# 83427                                     C#;Java;Python
# 83428                      Bash/Shell;Node.js;TypeScript
# 83429  C#;Go;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 83430                         APL;Clojure;Haskell;LISP;R
# 83431  C#;Dart;HTML/CSS;JavaScript;Kotlin;Node.js;Pyt...
# 83432                               Java;Ruby;TypeScript
# 83433                                             Kotlin
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                   DatabaseHaveWorkedWith  \
# 83419  Elasticsearch;MariaDB;MySQL;Oracle;PostgreSQL;...
# 83420  Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...
# 83421                                              MySQL
# 83422                          MariaDB;PostgreSQL;SQLite
# 83423        Elasticsearch;MySQL;PostgreSQL;Redis;SQLite
# 83424                                              MySQL
# 83425                                   DynamoDB;MongoDB
# 83426           Microsoft SQL Server;MySQL;Oracle;SQLite
# 83427                                                NaN
# 83428             Elasticsearch;MongoDB;PostgreSQL;Redis
# 83429                           MongoDB;MySQL;PostgreSQL
# 83430                     MongoDB;MySQL;PostgreSQL;Redis
# 83431                              Firebase;MySQL;SQLite
# 83432                                   MySQL;PostgreSQL
# 83433                      Firebase;MongoDB;MySQL;SQLite
# 83434                                      Oracle;SQLite
# 83435     Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436    DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437   Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                  Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 83419  Cassandra;Elasticsearch;MariaDB;MySQL;Oracle;P...
# 83420                        Elasticsearch;MongoDB;Redis
# 83421                               DynamoDB;MySQL;Redis
# 83422                                  PostgreSQL;SQLite
# 83423                      MySQL;PostgreSQL;Redis;SQLite
# 83424                                         PostgreSQL
# 83425                                                NaN
# 83426                                       MySQL;SQLite
# 83427                                                NaN
# 83428                     Elasticsearch;PostgreSQL;Redis
# 83429  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
# 83430                                         PostgreSQL
# 83431             DynamoDB;Firebase;MongoDB;MySQL;SQLite
# 83432                                                NaN
# 83433                                                NaN
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#                               PlatformHaveWorkedWith  \
# 83419                                            AWS
# 83420                                            NaN
# 83421                                            AWS
# 83422                                            NaN
# 83423  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83424         AWS;DigitalOcean;Google Cloud Platform
# 83425                                            AWS
# 83426                                            AWS
# 83427                                            NaN
# 83428                      AWS;Google Cloud Platform
# 83429                                         Heroku
# 83430  AWS;DigitalOcean;Google Cloud Platform;Heroku
# 83431                          Google Cloud Platform
# 83432                   Google Cloud Platform;Heroku
# 83433                                            NaN
# 83434                                            AWS
# 83435                                            NaN
# 83436                      AWS;Google Cloud Platform
# 83437                                         Heroku
# 83438                                Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 83419                                AWS;Microsoft Azure
# 83420                                                NaN
# 83421          AWS;Google Cloud Platform;Microsoft Azure
# 83422                                                NaN
# 83423            AWS;DigitalOcean;Heroku;Microsoft Azure
# 83424                                                NaN
# 83425                                       DigitalOcean
# 83426                                                NaN
# 83427                                                NaN
# 83428                          AWS;Google Cloud Platform
# 83429  AWS;Heroku;IBM Cloud or Watson;Microsoft Azure...
# 83430             AWS;DigitalOcean;Google Cloud Platform
# 83431                          AWS;Google Cloud Platform
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                AWS
# 83435                                                NaN
# 83436                                                AWS
# 83437                                   AWS;DigitalOcean
# 83438                                                AWS
#
#                                   WebframeHaveWorkedWith  \
# 83419                                     Angular;Spring
# 83420  Angular;ASP.NET;ASP.NET Core ;Express;React.js...
# 83421                             Django;jQuery;React.js
# 83422                                      Ruby on Rails
# 83423       Django;Flask;Laravel;React.js;Symfony;Vue.js
# 83424                           Angular.js;Spring;Vue.js
# 83425                                   Express;React.js
# 83426                         Django;Flask;jQuery;Spring
# 83427                                      Angular;Flask
# 83428                                           React.js
# 83429                                Django;Flask;jQuery
# 83430                      Django;React.js;Ruby on Rails
# 83431                                       Flask;jQuery
# 83432                Flask;React.js;Ruby on Rails;Vue.js
# 83433                                           React.js
# 83434                                                NaN
# 83435       Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                      FastAPI;Flask
# 83437                      Django;Express;Flask;React.js
# 83438                                     Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 83419      Angular;Express;React.js;Spring;Svelte;Vue.js
# 83420                     Express;React.js;Spring;Vue.js
# 83421                                      Django;Vue.js
# 83422                                      Ruby on Rails
# 83423  Django;FastAPI;Flask;Gatsby;Laravel;React.js;V...
# 83424                                             Spring
# 83425                                             Vue.js
# 83426                                       Django;Flask
# 83427                                            Angular
# 83428                                           React.js
# 83429  Angular.js;ASP.NET;ASP.NET Core ;Django;FastAP...
# 83430                                                NaN
# 83431                Angular;Django;Flask;jQuery;Laravel
# 83432                                                NaN
# 83433                                                NaN
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                                MiscTechHaveWorkedWith  \
# 83419                                  .NET Framework
# 83420  .NET Framework;.NET Core / .NET 5;Apache Spark
# 83421                                             NaN
# 83422                                             NaN
# 83423                                         Flutter
# 83424                                             NaN
# 83425                                    React Native
# 83426                                           NumPy
# 83427                                             NaN
# 83428                                    React Native
# 83429                                    NumPy;Pandas
# 83430                                             NaN
# 83431                                         Flutter
# 83432           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83433                                    React Native
# 83434                                             NaN
# 83435                                      Flutter;Qt
# 83436                       Hadoop;Keras;NumPy;Pandas
# 83437           NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                             NaN
#
#                                   MiscTechWantToWorkWith  \
# 83419                                                NaN
# 83420              Apache Spark;TensorFlow;Torch/PyTorch
# 83421                                                NaN
# 83422                                                NaN
# 83423                   Flutter;TensorFlow;Torch/PyTorch
# 83424                                                NaN
# 83425                                            Flutter
# 83426                                              NumPy
# 83427                                                NaN
# 83428                               Flutter;React Native
# 83429     .NET Framework;.NET Core / .NET 5;NumPy;Pandas
# 83430                                                NaN
# 83431      Flutter;Hadoop;NumPy;TensorFlow;Torch/PyTorch
# 83432                                                NaN
# 83433                                            Flutter
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#                                  ToolsTechHaveWorkedWith  \
# 83419                    Docker;Git;Kubernetes;Terraform
# 83420  Ansible;Deno;Docker;Git;Kubernetes;Puppet;Terr...
# 83421                                         Docker;Git
# 83422                                                Git
# 83423                                    Docker;Git;Yarn
# 83424                    Docker;Git;Kubernetes;Terraform
# 83425                                 Git;Terraform;Yarn
# 83426                                                Git
# 83427                     Ansible;Git;Terraform;Unity 3D
# 83428                          Docker;Git;Terraform;Yarn
# 83429                                                Git
# 83430                                         Docker;Git
# 83431                                                Git
# 83432                         Docker;Git;Kubernetes;Yarn
# 83433                                    Docker;Git;Yarn
# 83434                                         Docker;Git
# 83435                         Git;Unity 3D;Unreal Engine
# 83436                       Ansible;Docker;Git;Terraform
# 83437                       Ansible;Docker;Git;Terraform
# 83438                                         Docker;Git
#
#                                  ToolsTechWantToWorkWith  \
# 83419            Ansible;Docker;Git;Kubernetes;Terraform
# 83420  Deno;Docker;Git;Kubernetes;Unity 3D;Unreal Eng...
# 83421                    Docker;Git;Kubernetes;Terraform
# 83422                                                Git
# 83423                         Docker;Git;Kubernetes;Yarn
# 83424                              Docker;Git;Kubernetes
# 83425                                             Docker
# 83426                                Docker;Git;Unity 3D
# 83427                     Ansible;Git;Terraform;Unity 3D
# 83428                          Docker;Git;Terraform;Yarn
# 83429                                 Docker;Git;Xamarin
# 83430                     Docker;Git;Kubernetes;Unity 3D
# 83431                                         Docker;Git
# 83432                                                NaN
# 83433                                         Docker;Git
# 83434                                     Git;Kubernetes
# 83435                              Docker;Git;Kubernetes
# 83436                    Docker;Git;Kubernetes;Terraform
# 83437                               Kubernetes;Terraform
# 83438                              Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 83419  Android Studio;IntelliJ;Notepad++;Visual Studi...
# 83420  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83421                               IntelliJ;PyCharm;Vim
# 83422                                 Visual Studio Code
# 83423                       Android Studio;Visual Studio
# 83424                                IntelliJ;Neovim;Vim
# 83425                                           Webstorm
# 83426                 Eclipse;NetBeans;Vim;Visual Studio
# 83427  Eclipse;IntelliJ;NetBeans;Sublime Text;Visual ...
# 83428                        Visual Studio Code;Webstorm
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                          Emacs;Vim
# 83431  Android Studio;IntelliJ;IPython/Jupyter;Notepa...
# 83432        Atom;IPython/Jupyter;Vim;Visual Studio Code
# 83433            Android Studio;Visual Studio Code;Xcode
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith  \
# 83419                                 IntelliJ;Notepad++
# 83420  IntelliJ;IPython/Jupyter;Visual Studio Code;We...
# 83421                 Atom;IntelliJ;PyCharm;Vim;Webstorm
# 83422                                 Visual Studio Code
# 83423                        PyCharm;Visual Studio;Xcode
# 83424                                    IntelliJ;Neovim
# 83425                                                NaN
# 83426                                       NetBeans;Vim
# 83427           IntelliJ;Sublime Text;Visual Studio Code
# 83428                                 Visual Studio Code
# 83429     Atom;Notepad++;Sublime Text;Visual Studio Code
# 83430                                              Emacs
# 83431  Android Studio;IntelliJ;IPython/Jupyter;PyChar...
# 83432                                                NaN
# 83433                               Android Studio;Xcode
# 83434                                   Sublime Text;Vim
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim
# 83437                                                NaN
# 83438               IntelliJ;PHPStorm;Visual Studio Code
#
#                                    OpSys  \
# 83419  Windows Subsystem for Linux (WSL)
# 83420                            Windows
# 83421                              MacOS
# 83422                        Linux-based
# 83423                              MacOS
# 83424                              MacOS
# 83425                            Windows
# 83426                        Linux-based
# 83427                            Windows
# 83428                              MacOS
# 83429                            Windows
# 83430                        Linux-based
# 83431                            Windows
# 83432                              MacOS
# 83433                              MacOS
# 83434                              MacOS
# 83435                        Linux-based
# 83436                            Windows
# 83437                              MacOS
# 83438                        Linux-based
#
#                                                 NEWStuck  \
# 83419  Call a coworker or friend;Visit Stack Overflow...
# 83420                     Visit Stack Overflow;Google it
# 83421  Call a coworker or friend;Visit Stack Overflow...
# 83422                                          Google it
# 83423  Call a coworker or friend;Visit Stack Overflow...
# 83424  Call a coworker or friend;Visit Stack Overflow...
# 83425  Visit Stack Overflow;Google it;Watch help / tu...
# 83426  Call a coworker or friend;Visit Stack Overflow...
# 83427  Call a coworker or friend;Visit Stack Overflow...
# 83428  Call a coworker or friend;Visit Stack Overflow...
# 83429  Visit Stack Overflow;Google it;Watch help / tu...
# 83430  Call a coworker or friend;Visit Stack Overflow...
# 83431  Visit Stack Overflow;Go for a walk or other ph...
# 83432  Visit Stack Overflow;Go for a walk or other ph...
# 83433  Call a coworker or friend;Visit Stack Overflow...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 83419                      Stack Overflow;Stack Exchange
# 83420                                     Stack Overflow
# 83421                      Stack Overflow;Stack Exchange
# 83422                                     Stack Overflow
# 83423                      Stack Overflow;Stack Exchange
# 83424                      Stack Overflow;Stack Exchange
# 83425                                     Stack Overflow
# 83426                      Stack Overflow;Stack Exchange
# 83427                      Stack Overflow;Stack Exchange
# 83428                      Stack Overflow;Stack Exchange
# 83429                      Stack Overflow;Stack Exchange
# 83430                      Stack Overflow;Stack Exchange
# 83431                      Stack Overflow;Stack Exchange
# 83432                      Stack Overflow;Stack Exchange
# 83433                                     Stack Overflow
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq                SOAccount  \
# 83419            Daily or almost daily                      Yes
# 83420            Daily or almost daily                      Yes
# 83421            Daily or almost daily                      Yes
# 83422             A few times per week  Not sure/can't remember
# 83423           Multiple times per day                      Yes
# 83424             A few times per week                      Yes
# 83425           Multiple times per day  Not sure/can't remember
# 83426             A few times per week                       No
# 83427           Multiple times per day                      Yes
# 83428             A few times per week                      Yes
# 83429  A few times per month or weekly  Not sure/can't remember
# 83430             A few times per week                       No
# 83431           Multiple times per day                      Yes
# 83432            Daily or almost daily                       No
# 83433            Daily or almost daily                      Yes
# 83434             A few times per week                       No
# 83435           Multiple times per day                      Yes
# 83436             A few times per week                      Yes
# 83437  A few times per month or weekly                      Yes
# 83438             A few times per week                      Yes
#
#                                               SOPartFreq           SOComm  \
# 83419                    A few times per month or weekly    Yes, somewhat
# 83420  I have never participated in Q&A on Stack Over...          Neutral
# 83421                               A few times per week  Yes, definitely
# 83422                                                NaN    Yes, somewhat
# 83423                               A few times per week  Yes, definitely
# 83424                Less than once per month or monthly   No, not really
# 83425                                                NaN   No, not really
# 83426                                                NaN          Neutral
# 83427                    A few times per month or weekly    Yes, somewhat
# 83428                Less than once per month or monthly    Yes, somewhat
# 83429                                                NaN    Yes, somewhat
# 83430                                                NaN   No, not really
# 83431                    A few times per month or weekly  Yes, definitely
# 83432                                                NaN   No, not really
# 83433                    A few times per month or weekly    Yes, somewhat
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age                      Gender Trans  \
# 83419           Yes  35-44 years old                         Man    No
# 83420           Yes  25-34 years old                         Man    No
# 83421            No  35-44 years old                       Woman    No
# 83422            No  35-44 years old                         Man    No
# 83423           Yes  25-34 years old                         Man    No
# 83424            No  25-34 years old                         Man    No
# 83425            No  18-24 years old                         Man    No
# 83426            No  18-24 years old                         Man    No
# 83427            No  25-34 years old                         Man    No
# 83428           Yes  25-34 years old                         Man    No
# 83429            No  25-34 years old  Man;Or, in your own words:   Yes
# 83430            No  45-54 years old                         Man    No
# 83431            No  18-24 years old                         Man    No
# 83432            No  18-24 years old                       Woman    No
# 83433            No  25-34 years old                         Man    No
# 83434            No  25-34 years old                         Man    No
# 83435            No  18-24 years old                         Man    No
# 83436            No  25-34 years old                         Man    No
# 83437            No  25-34 years old                         Man    No
# 83438            No  18-24 years old                         Man    No
#
#                      Sexuality                     Ethnicity  \
# 83419  Straight / Heterosexual  White or of European descent
# 83420  Straight / Heterosexual  White or of European descent
# 83421  Straight / Heterosexual  White or of European descent
# 83422  Straight / Heterosexual  White or of European descent
# 83423  Straight / Heterosexual   Black or of African descent
# 83424  Straight / Heterosexual  White or of European descent
# 83425  Straight / Heterosexual  White or of European descent
# 83426                 Bisexual  White or of European descent
# 83427  Straight / Heterosexual  White or of European descent
# 83428  Straight / Heterosexual        Hispanic or Latino/a/x
# 83429                    Queer  White or of European descent
# 83430  Straight / Heterosexual  White or of European descent
# 83431  Straight / Heterosexual               Southeast Asian
# 83432  Straight / Heterosexual                    East Asian
# 83433  Straight / Heterosexual        Hispanic or Latino/a/x
# 83434  Straight / Heterosexual  White or of European descent
# 83435  Straight / Heterosexual   Black or of African descent
# 83436                      NaN  White or of European descent
# 83437  Straight / Heterosexual  White or of European descent
# 83438  Straight / Heterosexual        Hispanic or Latino/a/x
#
#                                            Accessibility  \
# 83419                                  None of the above
# 83420                                  None of the above
# 83421                                  None of the above
# 83422                                  None of the above
# 83423                                  None of the above
# 83424                                  None of the above
# 83425                                  None of the above
# 83426                                  None of the above
# 83427                                  None of the above
# 83428                                  None of the above
# 83429  I am unable to / find it difficult to walk or ...
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                                  None of the above
# 83434                                  None of the above
# 83435                                  None of the above
# 83436                                  None of the above
# 83437                                  None of the above
# 83438                                  None of the above
#
#                                             MentalHealth  \
# 83419                                  None of the above
# 83420  I have a mood or emotional disorder (e.g. depr...
# 83421                                  None of the above
# 83422                                  None of the above
# 83423                                  None of the above
# 83424                             Or, in your own words:
# 83425                                  None of the above
# 83426  I have a concentration and/or memory disorder ...
# 83427  I have an anxiety disorder;Or, in your own words:
# 83428                                  None of the above
# 83429                         I have an anxiety disorder
# 83430                                  None of the above
# 83431                                  None of the above
# 83432                                  None of the above
# 83433                         I have an anxiety disorder
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 83419  Appropriate in length                        Easy              83236.0
# 83420  Appropriate in length                        Easy              35672.0
# 83421  Appropriate in length  Neither easy nor difficult              88474.0
# 83422  Appropriate in length                        Easy              20000.0
# 83423  Appropriate in length  Neither easy nor difficult              25000.0
# 83424  Appropriate in length                        Easy             129718.0
# 83425  Appropriate in length                        Easy              19452.0
# 83426  Appropriate in length                        Easy                  NaN
# 83427              Too short                        Easy            4300000.0
# 83428  Appropriate in length  Neither easy nor difficult              41232.0
# 83429  Appropriate in length  Neither easy nor difficult                  NaN
# 83430  Appropriate in length                        Easy             125000.0
# 83431  Appropriate in length                        Easy              11676.0
# 83432  Appropriate in length                        Easy              80169.0
# 83433  Appropriate in length                        Easy              18326.0
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0

# %%
df.loc[300:400]
# Out:
#      ResponseId                              MainBranch  \
# 300         301          I am a developer by profession
# 301         302          I am a developer by profession
# 302         303             I code primarily as a hobby
# 303         304  I am a student who is learning to code
# 304         305          I am a developer by profession
# ..          ...                                     ...
# 396         397          I am a developer by profession
# 397         398          I am a developer by profession
# 398         399          I am a developer by profession
# 399         400          I am a developer by profession
# 400         401             I code primarily as a hobby
#
#                                             Employment  \
# 300                                 Employed full-time
# 301                                 Employed full-time
# 302  Independent contractor, freelancer, or self-em...
# 303                                 Student, full-time
# 304  Independent contractor, freelancer, or self-em...
# ..                                                 ...
# 396                                 Employed full-time
# 397  Independent contractor, freelancer, or self-em...
# 398                                 Employed full-time
# 399                                 Employed full-time
# 400                                 Employed full-time
#
#                                                Country    US_State UK_Country  \
# 300                                              Spain         NaN        NaN
# 301                                              Spain         NaN        NaN
# 302                                        Philippines         NaN        NaN
# 303                                              India         NaN        NaN
# 304                       Iran, Islamic Republic of...         NaN        NaN
# ..                                                 ...         ...        ...
# 396                                        Switzerland         NaN        NaN
# 397  United Kingdom of Great Britain and Northern I...         NaN    England
# 398                           United States of America  California        NaN
# 399                                            Germany         NaN        NaN
# 400  United Kingdom of Great Britain and Northern I...         NaN    England
#
#                                                EdLevel     Age1stCode  \
# 300                 Professional degree (JD, MD, etc.)  18 - 24 years
# 301    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  18 - 24 years
# 302  Secondary school (e.g. American high school, G...  55 - 64 years
# 303       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 304  Some college/university study without earning ...  11 - 17 years
# ..                                                 ...            ...
# 396                                     Something else  11 - 17 years
# 397  Some college/university study without earning ...  18 - 24 years
# 398    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 399  Secondary school (e.g. American high school, G...  11 - 17 years
# 400       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                              LearnCode YearsCode YearsCodePro  \
# 300  Other online resources (ex: videos, blogs, etc...         9            5
# 301  Coding Bootcamp;Other online resources (ex: vi...        10           10
# 302  Other online resources (ex: videos, blogs, etc...         7          NaN
# 303  Coding Bootcamp;Other online resources (ex: vi...        13          NaN
# 304  Other online resources (ex: videos, blogs, etc...         5            3
# ..                                                 ...       ...          ...
# 396                                             School         6            1
# 397                            Other (please specify):        43           41
# 398                            Other (please specify):        25           20
# 399  Other online resources (ex: videos, blogs, etc...         8            7
# 400                                                NaN        12          NaN
#
#                                                DevType  \
# 300  Developer, mobile;Developer, front-end;Develop...
# 301                            Other (please specify):
# 302            Developer, mobile;Developer, full-stack
# 303                                                NaN
# 304                              Developer, full-stack
# ..                                                 ...
# 396                              Developer, full-stack
# 397  Engineer, data;Developer, back-end;Data or bus...
# 398  Developer, front-end;Developer, full-stack;Dev...
# 399  Developer, mobile;Developer, front-end;Develop...
# 400                            Other (please specify):
#
#                                                OrgSize  \
# 300                                 20 to 99 employees
# 301                           10,000 or more employees
# 302                                                NaN
# 303                                                NaN
# 304  Just me - I am a freelancer, sole proprietor, ...
# ..                                                 ...
# 396                                   2 to 9 employees
# 397                                   2 to 9 employees
# 398                               500 to 999 employees
# 399                                 10 to 19 employees
# 400                                                NaN
#
#                       Currency   CompTotal CompFreq  \
# 300          EUR European Euro     30000.0   Yearly
# 301          EUR European Euro      1000.0  Monthly
# 302                        NaN         NaN      NaN
# 303                        NaN         NaN      NaN
# 304          IRR\tIranian rial  15000000.0  Monthly
# ..                         ...         ...      ...
# 396           CHF\tSwiss franc      4500.0  Monthly
# 397        GBP\tPound sterling         NaN   Yearly
# 398  USD\tUnited States dollar    108000.0   Yearly
# 399          EUR European Euro     54000.0   Yearly
# 400                        NaN         NaN      NaN
#
#                                 LanguageHaveWorkedWith  \
# 300                                      Kotlin;Python
# 301  Assembly;Bash/Shell;C;C#;C++;Go;HTML/CSS;Java;...
# 302                                              Swift
# 303      C;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 304         HTML/CSS;JavaScript;Node.js;SQL;TypeScript
# ..                                                 ...
# 396                 HTML/CSS;JavaScript;PHP;Python;SQL
# 397                              Bash/Shell;Python;SQL
# 398                                           C;C#;SQL
# 399  Dart;HTML/CSS;JavaScript;Node.js;PHP;SQL;TypeS...
# 400                            HTML/CSS;JavaScript;PHP
#
#                                 LanguageWantToWorkWith  \
# 300                                      Kotlin;Python
# 301  Bash/Shell;C#;C++;Crystal;Dart;Delphi;Elixir;E...
# 302                                              Swift
# 303                                       Java;PHP;SQL
# 304  Go;HTML/CSS;JavaScript;Node.js;Rust;SQL;TypeSc...
# ..                                                 ...
# 396                 HTML/CSS;JavaScript;PHP;Python;SQL
# 397                              Bash/Shell;Python;SQL
# 398                                           C;C#;SQL
# 399  Dart;HTML/CSS;JavaScript;Node.js;PHP;SQL;TypeS...
# 400                                       C;C#;C++;VBA
#
#                                 DatabaseHaveWorkedWith  \
# 300                                   PostgreSQL;Redis
# 301  Microsoft SQL Server;MongoDB;MySQL;Oracle;Post...
# 302                                              MySQL
# 303                      Firebase;MongoDB;MySQL;SQLite
# 304            Firebase;MongoDB;MySQL;PostgreSQL;Redis
# ..                                                 ...
# 396                                              MySQL
# 397                  Microsoft SQL Server;MySQL;SQLite
# 398                               Microsoft SQL Server
# 399                       Elasticsearch;Firebase;MySQL
# 400                                      MariaDB;MySQL
#
#                                 DatabaseWantToWorkWith  \
# 300                                   PostgreSQL;Redis
# 301  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 302                                              MySQL
# 303                      Firebase;MongoDB;MySQL;SQLite
# 304                                        MySQL;Redis
# ..                                                 ...
# 396                                              MySQL
# 397                  Microsoft SQL Server;MySQL;SQLite
# 398     Microsoft SQL Server;MongoDB;PostgreSQL;SQLite
# 399                       Elasticsearch;Firebase;MySQL
# 400                                                NaN
#
#         PlatformHaveWorkedWith  \
# 300            Microsoft Azure
# 301                        NaN
# 302                        NaN
# 303  AWS;Google Cloud Platform
# 304                     Heroku
# ..                         ...
# 396                        NaN
# 397    AWS;IBM Cloud or Watson
# 398                        NaN
# 399      Google Cloud Platform
# 400                        NaN
#
#                                 PlatformWantToWorkWith  \
# 300                                    Microsoft Azure
# 301                                                NaN
# 302                                                NaN
# 303                          AWS;Google Cloud Platform
# 304                                       DigitalOcean
# ..                                                 ...
# 396                                                NaN
# 397  AWS;Google Cloud Platform;IBM Cloud or Watson;...
# 398                                                NaN
# 399                              Google Cloud Platform
# 400                                                NaN
#
#                                 WebframeHaveWorkedWith  \
# 300                                     Angular;Django
# 301  Angular;Django;Drupal;jQuery;Laravel;React.js;...
# 302                                                NaN
# 303                                      Django;jQuery
# 304                            Express;React.js;Vue.js
# ..                                                 ...
# 396                                     jQuery;Symfony
# 397                                                NaN
# 398                                             Vue.js
# 399                   Angular;Express;React.js;Symfony
# 400                                             jQuery
#
#                                 WebframeWantToWorkWith  \
# 300                     Angular;Django;React.js;Vue.js
# 301  Angular;Angular.js;ASP.NET;ASP.NET Core ;Djang...
# 302                                                NaN
# 303                                      Django;jQuery
# 304                                     Express;Vue.js
# ..                                                 ...
# 396                                            Symfony
# 397                                                NaN
# 398                                             Vue.js
# 399                   Angular;Express;React.js;Symfony
# 400                     ASP.NET;ASP.NET Core ;React.js
#
#                 MiscTechHaveWorkedWith  \
# 300                                NaN
# 301                       NumPy;Pandas
# 302                                NaN
# 303                            Flutter
# 304                                NaN
# ..                                 ...
# 396                                NaN
# 397      Keras;NumPy;Pandas;TensorFlow
# 398  .NET Framework;.NET Core / .NET 5
# 399                            Flutter
# 400                                NaN
#
#                                 MiscTechWantToWorkWith  \
# 300                                                NaN
# 301  .NET Framework;.NET Core / .NET 5;Apache Spark...
# 302                                                NaN
# 303                                            Flutter
# 304                                                NaN
# ..                                                 ...
# 396                                                NaN
# 397                      Keras;NumPy;Pandas;TensorFlow
# 398                  .NET Framework;.NET Core / .NET 5
# 399                                            Flutter
# 400                                                NaN
#
#          ToolsTechHaveWorkedWith  \
# 300        Docker;Git;Kubernetes
# 301  Docker;Git;Unity 3D;Xamarin
# 302                          Git
# 303                          Git
# 304              Docker;Git;Yarn
# ..                           ...
# 396                   Docker;Git
# 397                          Git
# 398                          Git
# 399                     Git;Yarn
# 400                          NaN
#
#                                ToolsTechWantToWorkWith  \
# 300                              Docker;Git;Kubernetes
# 301  Ansible;Chef;Deno;Docker;Flow;Git;Kubernetes;P...
# 302                                                Git
# 303                                                Git
# 304                                      Deno;Git;Yarn
# ..                                                 ...
# 396                                                NaN
# 397                                                Git
# 398                                         Docker;Git
# 399                                           Git;Yarn
# 400                                                NaN
#
#                           NEWCollabToolsHaveWorkedWith  \
# 300          Android Studio;PyCharm;Visual Studio Code
# 301  Eclipse;IntelliJ;IPython/Jupyter;NetBeans;Note...
# 302                                              Xcode
# 303  Android Studio;Atom;IntelliJ;Notepad++;PyCharm...
# 304                                 Visual Studio Code
# ..                                                 ...
# 396                    PHPStorm;Vim;Visual Studio Code
# 397    IPython/Jupyter;Notepad++;RStudio;Visual Studio
# 398                                      Visual Studio
# 399         Android Studio;PHPStorm;Visual Studio Code
# 400                                       Sublime Text
#
#                           NEWCollabToolsWantToWorkWith        OpSys  \
# 300                             Atom;IntelliJ;Webstorm  Linux-based
# 301  Android Studio;Atom;Eclipse;Emacs;IntelliJ;IPy...      Windows
# 302                                              Xcode        MacOS
# 303  Android Studio;Atom;IntelliJ;Notepad++;PyCharm...      Windows
# 304                                 Visual Studio Code      Windows
# ..                                                 ...          ...
# 396                                                NaN  Linux-based
# 397    IPython/Jupyter;Notepad++;RStudio;Visual Studio  Linux-based
# 398          IntelliJ;Visual Studio;Visual Studio Code      Windows
# 399         Android Studio;PHPStorm;Visual Studio Code      Windows
# 400                                                NaN      Windows
#
#                                               NEWStuck  \
# 300  Call a coworker or friend;Visit Stack Overflow...
# 301  Call a coworker or friend;Visit Stack Overflow...
# 302  Visit Stack Overflow;Go for a walk or other ph...
# 303  Visit Stack Overflow;Google it;Watch help / tu...
# 304                                          Google it
# ..                                                 ...
# 396                                    Google it;Panic
# 397  Visit Stack Overflow;Go for a walk or other ph...
# 398  Visit Stack Overflow;Go for a walk or other ph...
# 399  Visit Stack Overflow;Go for a walk or other ph...
# 400  Visit Stack Overflow;Google it;Visit another d...
#
#                                             NEWSOSites  \
# 300                                     Stack Overflow
# 301  Stack Overflow;Stack Exchange;Stack Overflow f...
# 302                      Stack Overflow;Stack Exchange
# 303  Stack Overflow;Stack Overflow for Teams (priva...
# 304                      Stack Overflow;Stack Exchange
# ..                                                 ...
# 396                      Stack Overflow;Stack Exchange
# 397                      Stack Overflow;Stack Exchange
# 398                      Stack Overflow;Stack Exchange
# 399                      Stack Overflow;Stack Exchange
# 400                      Stack Overflow;Stack Exchange
#
#                              SOVisitFreq SOAccount  \
# 300               Multiple times per day       Yes
# 301                Daily or almost daily       Yes
# 302               Multiple times per day       Yes
# 303                Daily or almost daily       Yes
# 304                 A few times per week       Yes
# ..                                   ...       ...
# 396                 A few times per week       Yes
# 397                Daily or almost daily       Yes
# 398                Daily or almost daily       Yes
# 399               Multiple times per day       Yes
# 400  Less than once per month or monthly       Yes
#
#                               SOPartFreq           SOComm NEWOtherComms  \
# 300  Less than once per month or monthly          Neutral            No
# 301  Less than once per month or monthly    Yes, somewhat            No
# 302  Less than once per month or monthly  Yes, definitely            No
# 303      A few times per month or weekly    Yes, somewhat            No
# 304  Less than once per month or monthly          Neutral           Yes
# ..                                   ...              ...           ...
# 396  Less than once per month or monthly   No, not really           Yes
# 397                Daily or almost daily  Yes, definitely           Yes
# 398                Daily or almost daily  Yes, definitely            No
# 399                 A few times per week    Yes, somewhat           Yes
# 400  Less than once per month or monthly  Yes, definitely           Yes
#
#                  Age                                             Gender  \
# 300  25-34 years old                                                Man
# 301  25-34 years old  Woman;Non-binary, genderqueer, or gender non-c...
# 302  55-64 years old                                                Man
# 303  18-24 years old                                                Man
# 304  18-24 years old                                                Man
# ..               ...                                                ...
# 396  18-24 years old                                                Man
# 397  55-64 years old                                                Man
# 398  55-64 years old                                                NaN
# 399  25-34 years old                             Or, in your own words:
# 400  25-34 years old                                                Man
#
#                       Trans                                         Sexuality  \
# 300                      No                           Straight / Heterosexual
# 301  Or, in your own words:  Straight / Heterosexual;Prefer to self-describe:
# 302                      No                           Straight / Heterosexual
# 303                      No                           Straight / Heterosexual
# 304                      No                           Straight / Heterosexual
# ..                      ...                                               ...
# 396                      No                           Straight / Heterosexual
# 397                      No                                               NaN
# 398                     NaN                                               NaN
# 399                     NaN                          Prefer to self-describe:
# 400                      No                           Straight / Heterosexual
#
#                                              Ethnicity  \
# 300                       White or of European descent
# 301  White or of European descent;Hispanic or Latin...
# 302                       White or of European descent
# 303                             Or, in your own words:
# 304                                     Middle Eastern
# ..                                                 ...
# 396                       White or of European descent
# 397                             Hispanic or Latino/a/x
# 398                                                NaN
# 399                                                NaN
# 400                        Black or of African descent
#
#                            Accessibility  \
# 300                    None of the above
# 301               Or, in your own words:
# 302                    None of the above
# 303                    None of the above
# 304                    None of the above
# ..                                   ...
# 396  I am blind / have difficulty seeing
# 397                                  NaN
# 398                    None of the above
# 399                    None of the above
# 400                    None of the above
#
#                                           MentalHealth           SurveyLength  \
# 300                                                NaN  Appropriate in length
# 301  I have a mood or emotional disorder (e.g. depr...  Appropriate in length
# 302                                  None of the above  Appropriate in length
# 303                                  None of the above  Appropriate in length
# 304                                  None of the above  Appropriate in length
# ..                                                 ...                    ...
# 396  I have a concentration and/or memory disorder ...  Appropriate in length
# 397                                                NaN  Appropriate in length
# 398  I have a concentration and/or memory disorder ...  Appropriate in length
# 399  I have a mood or emotional disorder (e.g. depr...  Appropriate in length
# 400  I have a mood or emotional disorder (e.g. depr...               Too long
#
#                      SurveyEase  ConvertedCompYearly
# 300                        Easy              32429.0
# 301  Neither easy nor difficult              12972.0
# 302                        Easy                  NaN
# 303                        Easy                  NaN
# 304                        Easy               4272.0
# ..                          ...                  ...
# 396  Neither easy nor difficult              54888.0
# 397                        Easy                  NaN
# 398                        Easy             108000.0
# 399                        Easy              58373.0
# 400                        Easy                  NaN
#
# [101 rows x 48 columns]

# %%
df.iloc[2:1+300]
# Out:
#      ResponseId                                         MainBranch  \
# 2             3  I am not primarily a developer, but I write co...
# 3             4                     I am a developer by profession
# 4             5                     I am a developer by profession
# 5             6             I am a student who is learning to code
# 6             7                        I code primarily as a hobby
# ..          ...                                                ...
# 296         297                     I am a developer by profession
# 297         298             I am a student who is learning to code
# 298         299                        I code primarily as a hobby
# 299         300                        I code primarily as a hobby
# 300         301                     I am a developer by profession
#
#                                             Employment  \
# 2                                   Student, full-time
# 3                                   Employed full-time
# 4    Independent contractor, freelancer, or self-em...
# 5                                   Student, part-time
# 6                                  I prefer not to say
# ..                                                 ...
# 296                                 Employed full-time
# 297                                 Student, full-time
# 298                                 Employed full-time
# 299                                 Employed full-time
# 300                                 Employed full-time
#
#                                                Country        US_State  \
# 2                                   Russian Federation             NaN
# 3                                              Austria             NaN
# 4    United Kingdom of Great Britain and Northern I...             NaN
# 5                             United States of America         Georgia
# 6                             United States of America   New Hampshire
# ..                                                 ...             ...
# 296                                             Brazil             NaN
# 297                                              India             NaN
# 298                           United States of America  South Carolina
# 299                                             France             NaN
# 300                                              Spain             NaN
#
#     UK_Country                                            EdLevel  \
# 2          NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3          NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4      England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5          NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6          NaN  Secondary school (e.g. American high school, G...
# ..         ...                                                ...
# 296        NaN  Some college/university study without earning ...
# 297        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 298        NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 299        NaN                 Professional degree (JD, MD, etc.)
# 300        NaN                 Professional degree (JD, MD, etc.)
#
#         Age1stCode                                          LearnCode  \
# 2    11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3    11 - 17 years                                                NaN
# 4     5 - 10 years                            Friend or family member
# 5    11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 6    11 - 17 years  Other online resources (ex: videos, blogs, etc...
# ..             ...                                                ...
# 296  18 - 24 years                                             School
# 297  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 298  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 299  35 - 44 years    Other online resources (ex: videos, blogs, etc)
# 300  18 - 24 years  Other online resources (ex: videos, blogs, etc...
#
#     YearsCode YearsCodePro                                            DevType  \
# 2         NaN          NaN                                                NaN
# 3         NaN          NaN                               Developer, front-end
# 4          17           10  Developer, desktop or enterprise applications;...
# 5         NaN          NaN                                                NaN
# 6           3          NaN                                                NaN
# ..        ...          ...                                                ...
# 296        12           12                               Developer, front-end
# 297         3          NaN                                                NaN
# 298        35          NaN                                          Scientist
# 299         3          NaN                            Other (please specify):
# 300         9            5  Developer, mobile;Developer, front-end;Develop...
#
#                                                OrgSize             Currency  \
# 2                                                  NaN                  NaN
# 3                                 100 to 499 employees    EUR European Euro
# 4    Just me - I am a freelancer, sole proprietor, ...  GBP\tPound sterling
# 5                                                  NaN                  NaN
# 6                                                  NaN                  NaN
# ..                                                 ...                  ...
# 296                                 10 to 19 employees  BRL\tBrazilian real
# 297                                                NaN                  NaN
# 298                                                NaN                  NaN
# 299                                                NaN                  NaN
# 300                                 20 to 99 employees    EUR European Euro
#
#      CompTotal CompFreq                             LanguageHaveWorkedWith  \
# 2          NaN      NaN                           Assembly;C;Python;R;Rust
# 3          NaN  Monthly                              JavaScript;TypeScript
# 4          NaN      NaN                     Bash/Shell;HTML/CSS;Python;SQL
# 5          NaN      NaN  C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 6          NaN      NaN                                HTML/CSS;JavaScript
# ..         ...      ...                                                ...
# 296     3200.0  Monthly                Dart;HTML/CSS;JavaScript;TypeScript
# 297        NaN      NaN  C++;Go;HTML/CSS;Java;JavaScript;Node.js;Python...
# 298        NaN      NaN                               Bash/Shell;PHP;R;SQL
# 299        NaN      NaN          Bash/Shell;HTML/CSS;PowerShell;Python;SQL
# 300    30000.0   Yearly                                      Kotlin;Python
#
#                                 LanguageWantToWorkWith  \
# 2                                    Julia;Python;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
# 5    C#;C++;Go;HTML/CSS;Java;JavaScript;Node.js;Obj...
# 6                              HTML/CSS;JavaScript;PHP
# ..                                                 ...
# 296        Dart;HTML/CSS;JavaScript;Node.js;TypeScript
# 297                               Go;Python;TypeScript
# 298     Bash/Shell;Clojure;Julia;LISP;PHP;Python;R;SQL
# 299  Bash/Shell;C;HTML/CSS;JavaScript;PowerShell;Py...
# 300                                      Kotlin;Python
#
#                       DatabaseHaveWorkedWith  \
# 2                                     SQLite
# 3                                        NaN
# 4             Elasticsearch;PostgreSQL;Redis
# 5                    MySQL;PostgreSQL;SQLite
# 6                                        NaN
# ..                                       ...
# 296                    Firebase;MySQL;SQLite
# 297  MariaDB;MongoDB;MySQL;PostgreSQL;SQLite
# 298                                  MariaDB
# 299                                   SQLite
# 300                         PostgreSQL;Redis
#
#                                 DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 2                                               SQLite                 Heroku
# 3                                                  NaN                    NaN
# 4             Cassandra;Elasticsearch;PostgreSQL;Redis                    NaN
# 5    Elasticsearch;Firebase;IBM DB2;MariaDB;Microso...                    NaN
# 6                                                  NaN                    NaN
# ..                                                 ...                    ...
# 296                              Firebase;MySQL;SQLite                    NaN
# 297                       Elasticsearch;Firebase;Redis                 Heroku
# 298                                            MariaDB                    NaN
# 299                                             SQLite                    NaN
# 300                                   PostgreSQL;Redis        Microsoft Azure
#
#                                 PlatformWantToWorkWith  \
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 296                                                NaN
# 297  AWS;DigitalOcean;Google Cloud Platform;IBM Clo...
# 298                                                NaN
# 299                                                NaN
# 300                                    Microsoft Azure
#
#                            WebframeHaveWorkedWith  \
# 2                                           Flask
# 3                                  Angular;jQuery
# 4                                           Flask
# 5                   Express;Flask;jQuery;React.js
# 6                                          jQuery
# ..                                            ...
# 296                                       Angular
# 297  Django;Express;Gatsby;jQuery;React.js;Vue.js
# 298                                       Laravel
# 299                                           NaN
# 300                                Angular;Django
#
#              WebframeWantToWorkWith  \
# 2                             Flask
# 3                    Angular;jQuery
# 4                             Flask
# 5     Express;Flask;jQuery;React.js
# 6                            jQuery
# ..                              ...
# 296          Angular;Express;Vue.js
# 297                 Gatsby;React.js
# 298                         Laravel
# 299                             NaN
# 300  Angular;Django;React.js;Vue.js
#
#                           MiscTechHaveWorkedWith  \
# 2          NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                            NaN
# 4               Apache Spark;Hadoop;NumPy;Pandas
# 5    Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 6                                            NaN
# ..                                           ...
# 296                                      Cordova
# 297                                          NaN
# 298                                          NaN
# 299                                 NumPy;Pandas
# 300                                          NaN
#
#                                 MiscTechWantToWorkWith  \
# 2          Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                  NaN
# 4                                  Hadoop;NumPy;Pandas
# 5    Keras;NumPy;Pandas;Qt;React Native;TensorFlow;...
# 6                                                  NaN
# ..                                                 ...
# 296                 .NET Core / .NET 5;Cordova;Flutter
# 297                                                NaN
# 298                                                NaN
# 299                         Flutter;Keras;NumPy;Pandas
# 300                                                NaN
#
#         ToolsTechHaveWorkedWith            ToolsTechWantToWorkWith  \
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4    Docker;Git;Kubernetes;Yarn         Docker;Git;Kubernetes;Yarn
# 5                           Git  Docker;Git;Unity 3D;Unreal Engine
# 6                           NaN                                NaN
# ..                          ...                                ...
# 296                  Docker;Git                Docker;Git;Unity 3D
# 297             Docker;Git;Yarn    Deno;Docker;Git;Kubernetes;Yarn
# 298                         Git                                Git
# 299                         Git                                Git
# 300       Docker;Git;Kubernetes              Docker;Git;Kubernetes
#
#                           NEWCollabToolsHaveWorkedWith  \
# 2    IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                  NaN
# 4           Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# 5    IPython/Jupyter;Notepad++;PyCharm;Sublime Text...
# 6                                                  NaN
# ..                                                 ...
# 296                    Sublime Text;Visual Studio Code
# 297                    Sublime Text;Visual Studio Code
# 298                                          Emacs;Vim
# 299                 IPython/Jupyter;Visual Studio Code
# 300          Android Studio;PyCharm;Visual Studio Code
#
#                           NEWCollabToolsWantToWorkWith        OpSys  \
# 2    IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                  NaN      Windows
# 4    Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# 5    Android Studio;IPython/Jupyter;Vim;Visual Stud...      Windows
# 6                                                  NaN      Windows
# ..                                                 ...          ...
# 296  Android Studio;Sublime Text;Visual Studio;Visu...  Linux-based
# 297                                 Visual Studio Code  Linux-based
# 298                                          Emacs;Vim  Linux-based
# 299                 IPython/Jupyter;Visual Studio Code      Windows
# 300                             Atom;IntelliJ;Webstorm  Linux-based
#
#                                               NEWStuck  \
# 2    Visit Stack Overflow;Google it;Watch help / tu...
# 3    Call a coworker or friend;Visit Stack Overflow...
# 4    Visit Stack Overflow;Go for a walk or other ph...
# 5    Visit Stack Overflow;Go for a walk or other ph...
# 6    Call a coworker or friend;Visit Stack Overflow...
# ..                                                 ...
# 296  Call a coworker or friend;Visit Stack Overflow...
# 297  Visit Stack Overflow;Google it;Watch help / tu...
# 298  Call a coworker or friend;Visit Stack Overflow...
# 299  Visit Stack Overflow;Go for a walk or other ph...
# 300  Call a coworker or friend;Visit Stack Overflow...
#
#                         NEWSOSites             SOVisitFreq SOAccount  \
# 2    Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 3                   Stack Overflow   Daily or almost daily       Yes
# 4    Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 5    Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 6                   Stack Overflow   Daily or almost daily       Yes
# ..                             ...                     ...       ...
# 296                 Stack Overflow  Multiple times per day       Yes
# 297  Stack Overflow;Stack Exchange    A few times per week       Yes
# 298  Stack Overflow;Stack Exchange   Daily or almost daily       Yes
# 299  Stack Overflow;Stack Exchange  Multiple times per day       Yes
# 300                 Stack Overflow  Multiple times per day       Yes
#
#                                             SOPartFreq           SOComm  \
# 2                               Multiple times per day  Yes, definitely
# 3                                Daily or almost daily          Neutral
# 4                                 A few times per week    Yes, somewhat
# 5    I have never participated in Q&A on Stack Over...    Yes, somewhat
# 6                                 A few times per week    Yes, somewhat
# ..                                                 ...              ...
# 296                              Daily or almost daily    Yes, somewhat
# 297                Less than once per month or monthly    Yes, somewhat
# 298                Less than once per month or monthly    Yes, somewhat
# 299                             Multiple times per day  Yes, definitely
# 300                Less than once per month or monthly          Neutral
#
#     NEWOtherComms                Age             Gender Trans  \
# 2             Yes    18-24 years old                Man    No
# 3              No    35-44 years old                Man    No
# 4              No    25-34 years old                Man    No
# 5              No    18-24 years old  Prefer not to say    No
# 6              No  Prefer not to say  Prefer not to say    No
# ..            ...                ...                ...   ...
# 296            No    25-34 years old                Man    No
# 297           Yes    18-24 years old                Man    No
# 298            No    45-54 years old                Man    No
# 299            No    45-54 years old                Man    No
# 300            No    25-34 years old                Man    No
#
#                    Sexuality                     Ethnicity  \
# 2          Prefer not to say             Prefer not to say
# 3    Straight / Heterosexual  White or of European descent
# 4                        NaN  White or of European descent
# 5    Straight / Heterosexual             Prefer not to say
# 6                        NaN                  I don't know
# ..                       ...                           ...
# 296  Straight / Heterosexual        Or, in your own words:
# 297  Straight / Heterosexual                   South Asian
# 298  Straight / Heterosexual                    East Asian
# 299  Straight / Heterosexual  White or of European descent
# 300  Straight / Heterosexual  White or of European descent
#
#                    Accessibility  \
# 2              None of the above
# 3    I am deaf / hard of hearing
# 4              None of the above
# 5              None of the above
# 6              None of the above
# ..                           ...
# 296            None of the above
# 297            None of the above
# 298            None of the above
# 299            None of the above
# 300            None of the above
#
#                                           MentalHealth           SurveyLength  \
# 2                                    None of the above  Appropriate in length
# 3                                                  NaN  Appropriate in length
# 4                                                  NaN  Appropriate in length
# 5    I have a concentration and/or memory disorder ...               Too long
# 6                                    None of the above  Appropriate in length
# ..                                                 ...                    ...
# 296                                  None of the above  Appropriate in length
# 297                                  None of the above               Too long
# 298                                  None of the above  Appropriate in length
# 299                                  None of the above  Appropriate in length
# 300                                                NaN  Appropriate in length
#
#                      SurveyEase  ConvertedCompYearly
# 2                          Easy                  NaN
# 3    Neither easy nor difficult                  NaN
# 4                          Easy                  NaN
# 5    Neither easy nor difficult                  NaN
# 6    Neither easy nor difficult                  NaN
# ..                          ...                  ...
# 296                        Easy               8796.0
# 297  Neither easy nor difficult                  NaN
# 298                        Easy                  NaN
# 299                        Easy                  NaN
# 300                        Easy              32429.0
#
# [299 rows x 48 columns]

# %%
result_schema = pd.read_csv('survey_results_schema.csv')

# %%
result_schema
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...       False      DB
# 1                                   Browser Meta Info       False    Meta
# 2   <span style="font-size:22px; font-family: aria...       False      DB
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
df_1=pd.DataFrame(df)

# %%
df_1
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country    US_State  \
# 0                                               Slovakia         NaN
# 1                                            Netherlands         NaN
# 2                                     Russian Federation         NaN
# 3                                                Austria         NaN
# 4      United Kingdom of Great Britain and Northern I...         NaN
# ...                                                  ...         ...
# 83434                           United States of America       Texas
# 83435                                              Benin         NaN
# 83436                           United States of America  New Jersey
# 83437                                             Canada         NaN
# 83438                                             Brazil         NaN
#
#       UK_Country                                            EdLevel  \
# 0            NaN  Secondary school (e.g. American high school, G...
# 1            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2            NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3            NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4        England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...          ...                                                ...
# 83434        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83435        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83436        NaN  Secondary school (e.g. American high school, G...
# 83437        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83438        NaN                 Professional degree (JD, MD, etc.)
#
#           Age1stCode                                          LearnCode  \
# 0      18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...
# 1      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 2      11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 3      11 - 17 years                                                NaN
# 4       5 - 10 years                            Friend or family member
# ...              ...                                                ...
# 83434  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83435  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83436  11 - 17 years                                             School
# 83437  11 - 17 years  Online Courses or Certification;Books / Physic...
# 83438  11 - 17 years                                             School
#
#       YearsCode YearsCodePro  \
# 0           NaN          NaN
# 1             7          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4            17           10
# ...         ...          ...
# 83434         6            5
# 83435         4            2
# 83436        10            4
# 83437         5            3
# 83438        14            4
#
#                                                  DevType  \
# 0                                      Developer, mobile
# 1                                                    NaN
# 2                                                    NaN
# 3                                   Developer, front-end
# 4      Developer, desktop or enterprise applications;...
# ...                                                  ...
# 83434                                Developer, back-end
# 83435                              Developer, full-stack
# 83436  Data scientist or machine learning specialist;...
# 83437                                Developer, back-end
# 83438  Developer, front-end;Developer, full-stack;Dev...
#
#                                                  OrgSize  \
# 0                                     20 to 99 employees
# 1                                                    NaN
# 2                                                    NaN
# 3                                   100 to 499 employees
# 4      Just me - I am a freelancer, sole proprietor, ...
# ...                                                  ...
# 83434                                 20 to 99 employees
# 83435  Just me - I am a freelancer, sole proprietor, ...
# 83436                           10,000 or more employees
# 83437                                 20 to 99 employees
# 83438                                       I don’t know
#
#                           Currency  CompTotal CompFreq  \
# 0                EUR European Euro     4800.0  Monthly
# 1                              NaN        NaN      NaN
# 2                              NaN        NaN      NaN
# 3                EUR European Euro        NaN  Monthly
# 4              GBP\tPound sterling        NaN      NaN
# ...                            ...        ...      ...
# 83434    USD\tUnited States dollar   160500.0   Yearly
# 83435  XOF\tWest African CFA franc   200000.0  Monthly
# 83436    USD\tUnited States dollar     1800.0   Weekly
# 83437         CAD\tCanadian dollar    90000.0  Monthly
# 83438          BRL\tBrazilian real     7700.0  Monthly
#
#                               LanguageHaveWorkedWith  \
# 0      C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                  JavaScript;Python
# 2                           Assembly;C;Python;R;Rust
# 3                              JavaScript;TypeScript
# 4                     Bash/Shell;HTML/CSS;Python;SQL
# ...                                              ...
# 83434                             Clojure;Kotlin;SQL
# 83435                                            NaN
# 83436                             Groovy;Java;Python
# 83437           Bash/Shell;JavaScript;Node.js;Python
# 83438         Delphi;Elixir;HTML/CSS;Java;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                  Swift
# 1                                                    NaN
# 2                                      Julia;Python;Rust
# 3                                  JavaScript;TypeScript
# 4                         Bash/Shell;HTML/CSS;Python;SQL
# ...                                                  ...
# 83434                                            Clojure
# 83435                                                NaN
# 83436                                        Java;Python
# 83437                                            Go;Rust
# 83438  Elixir;HTML/CSS;Java;JavaScript;Node.js;PHP;SQ...
#
#                                  DatabaseHaveWorkedWith  \
# 0                                     PostgreSQL;SQLite
# 1                                            PostgreSQL
# 2                                                SQLite
# 3                                                   NaN
# 4                        Elasticsearch;PostgreSQL;Redis
# ...                                                 ...
# 83434                                     Oracle;SQLite
# 83435    Firebase;MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 83436   DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83437  Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 83438                                 Oracle;PostgreSQL
#
#                                   DatabaseWantToWorkWith  \
# 0                                                 SQLite
# 1                                                    NaN
# 2                                                 SQLite
# 3                                                    NaN
# 4               Cassandra;Elasticsearch;PostgreSQL;Redis
# ...                                                  ...
# 83434                                             SQLite
# 83435  Firebase;MariaDB;MongoDB;MySQL;PostgreSQL;Redi...
# 83436                                     DynamoDB;Redis
# 83437                                                NaN
# 83438  Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;...
#
#           PlatformHaveWorkedWith PlatformWantToWorkWith  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                         Heroku                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ...                          ...                    ...
# 83434                        AWS                    AWS
# 83435                        NaN                    NaN
# 83436  AWS;Google Cloud Platform                    AWS
# 83437                     Heroku       AWS;DigitalOcean
# 83438            Microsoft Azure                    AWS
#
#                              WebframeHaveWorkedWith  \
# 0                                   Laravel;Symfony
# 1                              Angular;Flask;Vue.js
# 2                                             Flask
# 3                                    Angular;jQuery
# 4                                             Flask
# ...                                             ...
# 83434                                           NaN
# 83435  Django;jQuery;Laravel;React.js;Ruby on Rails
# 83436                                 FastAPI;Flask
# 83437                 Django;Express;Flask;React.js
# 83438                                Angular;Spring
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Flask
# 3                                         Angular;jQuery
# 4                                                  Flask
# ...                                                  ...
# 83434                                                NaN
# 83435  Django;Express;jQuery;Laravel;React.js;Ruby on...
# 83436                                      FastAPI;Flask
# 83437                                                NaN
# 83438                     Express;Laravel;Spring;Symfony
#
#                       MiscTechHaveWorkedWith  \
# 0                                        NaN
# 1                                    Cordova
# 2      NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                        NaN
# 4           Apache Spark;Hadoop;NumPy;Pandas
# ...                                      ...
# 83434                                    NaN
# 83435                             Flutter;Qt
# 83436              Hadoop;Keras;NumPy;Pandas
# 83437  NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                    NaN
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2            Keras;NumPy;Pandas;TensorFlow;Torch/PyTorch
# 3                                                    NaN
# 4                                    Hadoop;NumPy;Pandas
# ...                                                  ...
# 83434                                                NaN
# 83435                                                NaN
# 83436  Apache Spark;Hadoop;Keras;NumPy;Pandas;TensorFlow
# 83437              NumPy;Pandas;TensorFlow;Torch/PyTorch
# 83438                                                NaN
#
#             ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 0                               NaN                              NaN
# 1                   Docker;Git;Yarn                              Git
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4        Docker;Git;Kubernetes;Yarn       Docker;Git;Kubernetes;Yarn
# ...                             ...                              ...
# 83434                    Docker;Git                   Git;Kubernetes
# 83435    Git;Unity 3D;Unreal Engine            Docker;Git;Kubernetes
# 83436  Ansible;Docker;Git;Terraform  Docker;Git;Kubernetes;Terraform
# 83437  Ansible;Docker;Git;Terraform             Kubernetes;Terraform
# 83438                    Docker;Git            Docker;Git;Kubernetes
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                         PHPStorm;Xcode
# 1              Android Studio;IntelliJ;Notepad++;PyCharm
# 2      IPython/Jupyter;PyCharm;RStudio;Sublime Text;V...
# 3                                                    NaN
# 4             Atom;IPython/Jupyter;Notepad++;PyCharm;Vim
# ...                                                  ...
# 83434       IntelliJ;Sublime Text;Vim;Visual Studio Code
# 83435  Android Studio;Eclipse;Emacs;IntelliJ;NetBeans...
# 83436  Android Studio;Eclipse;IntelliJ;IPython/Jupyte...
# 83437                               PyCharm;Sublime Text
# 83438                        IntelliJ;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith        OpSys  \
# 0                                             Atom;Xcode        MacOS
# 1                                                    NaN      Windows
# 2      IPython/Jupyter;RStudio;Sublime Text;Visual St...        MacOS
# 3                                                    NaN      Windows
# 4      Atom;IPython/Jupyter;Notepad++;PyCharm;Vim;Vis...  Linux-based
# ...                                                  ...          ...
# 83434                                   Sublime Text;Vim        MacOS
# 83435  Emacs;IntelliJ;PHPStorm;PyCharm;RStudio;Sublim...  Linux-based
# 83436             IntelliJ;IPython/Jupyter;Notepad++;Vim      Windows
# 83437                                                NaN        MacOS
# 83438               IntelliJ;PHPStorm;Visual Studio Code  Linux-based
#
#                                                 NEWStuck  \
# 0      Call a coworker or friend;Visit Stack Overflow...
# 1                         Visit Stack Overflow;Google it
# 2      Visit Stack Overflow;Google it;Watch help / tu...
# 3      Call a coworker or friend;Visit Stack Overflow...
# 4      Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83434                Call a coworker or friend;Google it
# 83435  Call a coworker or friend;Visit Stack Overflow...
# 83436  Call a coworker or friend;Visit Stack Overflow...
# 83437  Call a coworker or friend;Visit Stack Overflow...
# 83438  Call a coworker or friend;Visit Stack Overflow...
#
#                                               NEWSOSites  \
# 0                                         Stack Overflow
# 1                                         Stack Overflow
# 2                          Stack Overflow;Stack Exchange
# 3                                         Stack Overflow
# 4                          Stack Overflow;Stack Exchange
# ...                                                  ...
# 83434                      Stack Overflow;Stack Exchange
# 83435                      Stack Overflow;Stack Exchange
# 83436                      Stack Overflow;Stack Exchange
# 83437                                     Stack Overflow
# 83438  Stack Overflow;Stack Exchange;Stack Overflow f...
#
#                            SOVisitFreq SOAccount  \
# 0               Multiple times per day       Yes
# 1                Daily or almost daily       Yes
# 2               Multiple times per day       Yes
# 3                Daily or almost daily       Yes
# 4                Daily or almost daily       Yes
# ...                                ...       ...
# 83434             A few times per week        No
# 83435           Multiple times per day       Yes
# 83436             A few times per week       Yes
# 83437  A few times per month or weekly       Yes
# 83438             A few times per week       Yes
#
#                                               SOPartFreq           SOComm  \
# 0                        A few times per month or weekly  Yes, definitely
# 1                                  Daily or almost daily  Yes, definitely
# 2                                 Multiple times per day  Yes, definitely
# 3                                  Daily or almost daily          Neutral
# 4                                   A few times per week    Yes, somewhat
# ...                                                  ...              ...
# 83434                                                NaN   No, not at all
# 83435  I have never participated in Q&A on Stack Over...    Yes, somewhat
# 83436  I have never participated in Q&A on Stack Over...   No, not really
# 83437                Less than once per month or monthly   No, not really
# 83438                               A few times per week    Yes, somewhat
#
#       NEWOtherComms              Age Gender Trans                Sexuality  \
# 0                No  25-34 years old    Man    No  Straight / Heterosexual
# 1                No  18-24 years old    Man    No  Straight / Heterosexual
# 2               Yes  18-24 years old    Man    No        Prefer not to say
# 3                No  35-44 years old    Man    No  Straight / Heterosexual
# 4                No  25-34 years old    Man    No                      NaN
# ...             ...              ...    ...   ...                      ...
# 83434            No  25-34 years old    Man    No  Straight / Heterosexual
# 83435            No  18-24 years old    Man    No  Straight / Heterosexual
# 83436            No  25-34 years old    Man    No                      NaN
# 83437            No  25-34 years old    Man    No  Straight / Heterosexual
# 83438            No  18-24 years old    Man    No  Straight / Heterosexual
#
#                           Ethnicity                Accessibility  \
# 0      White or of European descent            None of the above
# 1      White or of European descent            None of the above
# 2                 Prefer not to say            None of the above
# 3      White or of European descent  I am deaf / hard of hearing
# 4      White or of European descent            None of the above
# ...                             ...                          ...
# 83434  White or of European descent            None of the above
# 83435   Black or of African descent            None of the above
# 83436  White or of European descent            None of the above
# 83437  White or of European descent            None of the above
# 83438        Hispanic or Latino/a/x            None of the above
#
#                                             MentalHealth  \
# 0                                      None of the above
# 1                                      None of the above
# 2                                      None of the above
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 83434  I have a concentration and/or memory disorder ...
# 83435                                  None of the above
# 83436                                  None of the above
# 83437  I have a mood or emotional disorder (e.g. depr...
# 83438                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 0      Appropriate in length                        Easy              62268.0
# 1      Appropriate in length                        Easy                  NaN
# 2      Appropriate in length                        Easy                  NaN
# 3      Appropriate in length  Neither easy nor difficult                  NaN
# 4      Appropriate in length                        Easy                  NaN
# ...                      ...                         ...                  ...
# 83434  Appropriate in length                        Easy             160500.0
# 83435  Appropriate in length                        Easy               3960.0
# 83436  Appropriate in length  Neither easy nor difficult              90000.0
# 83437  Appropriate in length  Neither easy nor difficult             816816.0
# 83438  Appropriate in length                        Easy              21168.0
#
# [83439 rows x 48 columns]

# %%
df_1.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.loc[0:50, 'EdLevel':'DevType']
# Out:
#                                               EdLevel     Age1stCode  \
# 0   Secondary school (e.g. American high school, G...  18 - 24 years
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 3     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 4     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   5 - 10 years
# ..                                                ...            ...
# 46       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 47       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 48  Some college/university study without earning ...  11 - 17 years
# 49  Some college/university study without earning ...  11 - 17 years
# 50       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
#
#                                             LearnCode YearsCode YearsCodePro  \
# 0   Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 1   Other online resources (ex: videos, blogs, etc...         7          NaN
# 2   Other online resources (ex: videos, blogs, etc...       NaN          NaN
# 3                                                 NaN       NaN          NaN
# 4                             Friend or family member        17           10
# ..                                                ...       ...          ...
# 46    Other online resources (ex: videos, blogs, etc)         2          NaN
# 47                            Other (please specify):        39           35
# 48  Other online resources (ex: videos, blogs, etc...         7            1
# 49  Coding Bootcamp;Other online resources (ex: vi...       NaN          NaN
# 50                                          Colleague        12            6
#
#                                               DevType
# 0                                   Developer, mobile
# 1                                                 NaN
# 2                                                 NaN
# 3                                Developer, front-end
# 4   Developer, desktop or enterprise applications;...
# ..                                                ...
# 46                                                NaN
# 47                                                NaN
# 48      Developer, desktop or enterprise applications
# 49                                                NaN
# 50                              Developer, full-stack
#
# [51 rows x 6 columns]

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          35357
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       17512
# Some college/university study without earning a degree                                10589
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     9534
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2567
# Primary/elementary school                                                              2479
# Associate degree (A.A., A.S., etc.)                                                    2231
# Something else                                                                         1601
# Professional degree (JD, MD, etc.)                                                     1256
# Name: EdLevel, dtype: int64

# %%
df.loc[1:20,'Country']
# Out:
# 1                                           Netherlands
# 2                                    Russian Federation
# 3                                               Austria
# 4     United Kingdom of Great Britain and Northern I...
# 5                              United States of America
# 6                              United States of America
# 7                                              Malaysia
# 8                                                 India
# 9                                                Sweden
# 10    United Kingdom of Great Britain and Northern I...
# 11                                                Spain
# 12                                              Germany
# 13                                                 Peru
# 14    United Kingdom of Great Britain and Northern I...
# 15                             United States of America
# 16                                               Turkey
# 17                                               Canada
# 18                                            Singapore
# 19                                               Brazil
# 20                                              Germany
# Name: Country, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\SIVA\\Desktop\\PYTHON\\Pandas'
